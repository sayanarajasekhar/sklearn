# %% [markdown]
# <a href="https://colab.research.google.com/github/sayanarajasekhar/sklearn/blob/main/ScaleDataAndTrainModelUsingPipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install scikit-learn

# %%
from sklearn.datasets import fetch_california_housing
from sklearn.neighbors import KNeighborsRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
import matplotlib.pylab as plt

# %%
X,y = fetch_california_housing(return_X_y=True)

# %%
# Pipeline take list of tuples with name, object
# Create a pipeline with StandardScaler and KNeighborsRegression Model
pipe = Pipeline([
    ("scale", StandardScaler()),
    ("model", KNeighborsRegressor(n_neighbors=1))
])

# %%
# Run Pipeplie
pipe.fit(X,y)
# Out:
# Pipeline(steps=[('scale', StandardScaler()),
#                 ('model', KNeighborsRegressor(n_neighbors=1))])

# %%
pred = pipe.predict(X)

# %%
plt.scatter(pred, y)
