# %% [markdown]
# <a href="https://colab.research.google.com/github/sayanarajasekhar/sklearn/blob/main/first.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Installing scikit-learn
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.16.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)

# %%
# Importing california housing dataset and KNeighborsRegression
from sklearn.datasets import fetch_california_housing
from sklearn.neighbors import KNeighborsRegressor
from matplotlib.pylab import plt

# %%
# Getting features and values and assign to X,y
X, y = fetch_california_housing(return_X_y=True)

# %%
# create KNeighborsRegression model
model = KNeighborsRegressor()

# %%
# Fitting or Training model
model.fit(X,y)
# Out:
# KNeighborsRegressor()

# %%
# Using trained model to predict
pred = model.predict(X)

# %%
# Plotting predicted values and actual values
plt.scatter(pred, y)
